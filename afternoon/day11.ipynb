# %%
import cv2
import matplotlib.pyplot as plt

# %%
vid = cv2.VideoCapture(0)
vid
# Out:
# < cv2.VideoCapture 0x10a46f850>

# %%
vid.isOpened()
# Out:
# True

# %%
k = vid.read()

# %%
type(k), len(k)
# Out:
# (tuple, 2)

# %%
k
# Out:
# (True,
#  array([[[ 66, 147, 167],
#          [ 66, 146, 166],
#          [ 78, 151, 177],
#          ...,
#          [143, 215, 255],
#          [143, 216, 255],
#          [144, 217, 255]],
#
#         [[ 72, 148, 168],
#          [ 72, 147, 168],
#          [ 73, 142, 167],
#          ...,
#          [149, 219, 255],
#          [146, 217, 255],
#          [147, 218, 255]],
#
#         [[ 77, 142, 163],
#          [ 79, 143, 165],
#          [ 82, 144, 168],
#          ...,
#          [154, 221, 255],
#          [152, 220, 255],
#          [153, 220, 255]],
#
#         ...,
#
#         [[ 92, 112, 151],
#          [ 96, 117, 155],
#          [ 92, 117, 152],
#          ...,
#          [ 58,  78, 101],
#          [ 68,  85, 107],
#          [ 75,  91, 112]],
#
#         [[ 98, 117, 156],
#          [ 99, 119, 158],
#          [ 87, 113, 151],
#          ...,
#          [ 54,  80, 101],
#          [ 59,  84, 104],
#          [ 64,  89, 108]],
#
#         [[102, 120, 159],
#          [ 99, 119, 158],
#          [ 85, 111, 151],
#          ...,
#          [ 57,  86, 107],
#          [ 56,  83, 102],
#          [ 57,  84, 103]]], dtype=uint8))

# %%
flag, img = vid.read()

# %%
img.shape
# Out:
# (720, 1280, 3)

# %%
if flag:
    plt.imshow(img[:,::-1,::-1])

# %%
ord('a')
# Out:
# 97

# %%
for i in range(100):
    flag, img = vid.read()
    if flag:
        cv2.imshow('Preview', img)
        key = cv2.waitKey(1)
        if key == ord('x'):
            break
vid.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %%
from time import sleep

# %%
import cv2
from time import sleep

vid = cv2.VideoCapture(0)

while True:
    flag, img = vid.read()
    if flag:
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        cv2.imshow('Preview', img_gray)
        key = cv2.waitKey(1)
        if key == ord('q'):
            break
    else:
        break
    sleep(0.1)
vid.release()
cv2.destroyAllWindows()

cv2.waitKey(10)  # Only for Mac OS,  not for Windows
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 7
#       4 vid = cv2.VideoCapture(0)
#       6 while True:
# ----> 7     flag, img = vid.read()
#       8     if flag:
#       9         cv2.imshow('Preview', img)
#
# KeyboardInterrupt:

# %%
import cv2
from time import sleep

fd = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)
vid = cv2.VideoCapture(0)

while True:
    flag, img = vid.read()
    if flag:
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # x1, y1, w, h = (200, 400, 300, 400)
        faces = fd.detectMultiScale(img_gray, 1.1, 5)
        for x1,y1,w,h in faces:
            img_cropped = img[y1:y1+h, x1:x1+w, :]
            cv2.rectangle(
                img, 
                pt1=(x1,y1), pt2=(x1+w, y1+h),
                color=(0,0,255), thickness=10
            )
        cv2.imshow('Preview', img)
        key = cv2.waitKey(1)
        if key == ord('x'):
            break
    else:
        break
    sleep(0.1)
vid.release()
cv2.destroyAllWindows()

cv2.waitKey(10)  # Only for Mac OS,  not for Windows
# Out:
# -1

# %%
vid.release()

# %%
del vid
